# %%
from Model.stock import Stock
from Model.strategy import Strategy
from Model.indicator import Indicator

# %%
Strategy.compare()
# Out:
# SOPHIE : 4.76% in 426 trades.
# Average trade duration : 69 days.
# Number of won trades : 176
# Number of lost trades : 250
# Best trades
#     OPENING_DATE CLOSING_DATE                STOCK  STATUS  BUYING_PRICE  LAST_PRICE  PERFORMANCE
# 370   2016-07-12   2017-04-28  ST_MICROELECTRONICS  closed         5.375      14.350     2.667632
# 164   2016-06-22   2017-08-22               KERING  closed       152.250     308.700     2.025964
# 243   2014-12-09   2015-08-03              PEUGEOT  closed        10.560      18.245     1.726364
# 120   2016-08-15   2017-02-21      CREDIT_AGRICOLE  closed         8.250      11.615     1.406753
# 146   2014-09-03   2015-05-27              ESSILOR  closed        81.530     112.900     1.383659
# Worst trades
#     OPENING_DATE CLOSING_DATE                STOCK  STATUS  BUYING_PRICE  LAST_PRICE  PERFORMANCE
# 71    2016-03-16   2016-06-27          BNP_PARIBAS  closed        46.990      38.680     0.822495
# ...

# %%
Stock.ACCOR.visualize(strategy=Strategy.MICK)
# Out:
# /Users/hugofayolle/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
Stock.SOCIETE_GENERALE.visualize(strategy=Strategy.SAM)
# Out:
# /Users/hugofayolle/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ---

# %% [markdown]
# # Focus on SAM

# %%
focus = Strategy.SAM

# %%
focus.description
# Out:
# 'Sam buys if SMA50 > SMA100 and sells if not.'

# %%
focus.compare_stocks()

# %%
Stock.VEOLIA.visualize(focus)
# Out:
# /Users/hugofayolle/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
Stock.AXA.visualize(focus)
# Out:
# /Users/hugofayolle/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# Hypothesis : when entering the market, if stock has not raised one month later, sell
